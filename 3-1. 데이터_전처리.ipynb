# %%
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # scikit-learn으로 Normalization 해보기

# %%
from sklearn import preprocessing

# %%
nba_player_of_the_week_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Study/Code_It/ML/3. 머신러닝, 더 빠르고 정확하게/NBA_player_of_the_week.csv")
nba_player_of_the_week_df
# Out:
#                       Player                    Team Conference          Date  \
# 0               Jayson Tatum          Boston Celtics       East  Feb 10, 2020
# 1               Nikola Jokic          Denver Nuggets       West  Feb 10, 2020
# 2               Jaylen Brown          Boston Celtics       East   Feb 3, 2020
# 3             Damian Lillard  Portland Trail Blazers       West   Feb 3, 2020
# 4              Pascal Siakam         Toronto Raptors       East  Jan 27, 2020
# ...                      ...                     ...        ...           ...
# 1335               Phil Ford       Kansas City Kings        NaN  Nov 18, 1979
# 1336           Magic Johnson      Los Angeles Lakers        NaN  Nov 11, 1979
# 1337         Marques Johnson         Milwaukee Bucks        NaN   Nov 4, 1979
# 1338  Micheal Ray Richardson         New York Knicks        NaN  Oct 28, 1979
# 1339           Julius Erving     Philadelphia Sixers        NaN  Oct 21, 1979
#
# ...

# %%
nba_player_of_the_week_df.describe()
# Out:
#             Weight          Age   Draft Year  Seasons in league  Season short  \
# count  1340.000000  1340.000000  1340.000000        1340.000000   1340.000000
# mean    224.567164    26.738060  1996.287313           5.740299   2003.156716
# std      30.798885     3.400683    11.253558           3.293421     11.470164
# min     150.000000    19.000000  1965.000000           0.000000   1980.000000
# 25%     205.000000    24.000000  1987.000000           3.000000   1994.000000
# 50%     220.000000    26.000000  1998.000000           5.000000   2005.000000
# 75%     250.000000    29.000000  2005.000000           8.000000   2013.000000
# max     325.000000    40.000000  2018.000000          17.000000   2020.000000
#
#         Real_value    Height CM    Weight KG  Last Season
# count  1340.000000  1340.000000  1340.000000  1340.000000
# mean      0.686940   201.071642   101.384328     0.023881
# std       0.242007     9.367970    14.011226     0.152734
# ...

# %%
height_weight_age_df = nba_player_of_the_week_df[['Height CM','Weight KG', 'Age']]
height_weight_age_df.head()
# Out:
#    Height CM  Weight KG  Age
# 0        203         94   21
# 1        213        113   25
# 2        201         99   23
# 3        190         88   29
# 4        206        104   25

# %%
scaler = preprocessing.MinMaxScaler()
normalized_data = scaler.fit_transform(height_weight_age_df)

# %%
normalized_data
# Out:
# array([[0.51851852, 0.32911392, 0.0952381 ],
#        [0.7037037 , 0.56962025, 0.28571429],
#        [0.48148148, 0.39240506, 0.19047619],
#        ...,
#        [0.48148148, 0.37974684, 0.23809524],
#        [0.38888889, 0.21518987, 0.23809524],
#        [0.42592593, 0.27848101, 0.52380952]])

# %%
normalized_df = pd.DataFrame(normalized_data, columns=['Height', 'Weight', 'Age'])

# %%
normalized_df.describe()
# Out:
#             Height       Weight          Age
# count  1340.000000  1340.000000  1340.000000
# mean      0.482808     0.422586     0.368479
# std       0.173481     0.177357     0.161937
# min       0.000000     0.000000     0.000000
# 25%       0.333333     0.316456     0.238095
# 50%       0.481481     0.392405     0.333333
# 75%       0.611111     0.569620     0.476190
# max       1.000000     1.000000     1.000000

# %% [markdown]
# # One-Hot Encoding

# %%
titanic_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Study/Code_It/ML/3. 머신러닝, 더 빠르고 정확하게/titanic.csv',index_col=0)

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic_sex_embarked = titanic_df[['Sex', 'Embarked']]

# %%
titanic_sex_embarked.head()
# Out:
#       Sex Embarked
# 0    male        S
# 1  female        C
# 2  female        S
# 3  female        S
# 4    male        S

# %%
ohe = pd.get_dummies(titanic_sex_embarked)

# %%
ohe
# Out:
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0             0         1           0           0           1
# 1             1         0           1           0           0
# 2             1         0           0           0           1
# 3             1         0           0           0           1
# 4             0         1           0           0           1
# ..          ...       ...         ...         ...         ...
# 886           0         1           0           0           1
# 887           1         0           0           0           1
# 888           1         0           0           0           1
# 889           0         1           1           0           0
# 890           0         1           0           1           0
#
# [891 rows x 5 columns]

# %%
ohe2 = pd.get_dummies(data=titanic, columns=['Sex', 'Embarked'])

# %%
ohe2ㅇㄹㅇㄹㅇ
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 3             3         1       1
# 4             4         0       3
# ..          ...       ...     ...
# 886         886         0       2
# 887         887         1       1
# 888         888         0       3
# 889         889         1       1
# 890         890         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...
